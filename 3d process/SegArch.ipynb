# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %cd '//content//drive//My Drive//partseg//Pointnet_Pointnet2_pytorch-master//'
# %ls
# Out:
# /content/drive/My Drive/partseg/Pointnet_Pointnet2_pytorch-master
# data/        log/         __pycache__/   test_partseg.py
# data_utils/  models/      README.md      train_partseg.py
# LICENSE      provider.py  SegArch.ipynb  visualizer/

# %%
# !python train_partseg.py --model pointnet2_part_seg_msg --epoch 251 --batch_size 8 --log_dir test0326
# Out:
# PARAMETER ...
# Namespace(model='pointnet2_part_seg_msg', batch_size=8, epoch=251, learning_rate=0.001, gpu='0', optimizer='Adam', log_dir='test0326', decay_rate=0.0001, npoint=1024, normal=False, step_size=20, lr_decay=0.5)
# ...

# %%
# !python test_partseg.py --log_dir test0326 --batch_size 1 --num_point 1024
# Out:
# PARAMETER ...
# Namespace(batch_size=1, gpu='0', num_point=1024, log_dir='test0326', normal=False, num_votes=3)
# The number of test data is: 1
#   0% 0/1 [00:00<?, ?it/s]torch.Size([1, 1024, 3]) shapes
# 100% 1/1 [00:07<00:00,  7.27s/it]
# eval mIoU of Building       0.037695
# Accuracy is: 0.18848
# Class avg accuracy is: nan
# Class avg mIOU is: 0.03770
# Inctance avg mIOU is: 0.03770
